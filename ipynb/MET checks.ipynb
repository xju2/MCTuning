# %%
import yoda
# %matplotlib inline

yoda.mplinit()
# Out:
# <module 'matplotlib' from '/global/project/projectdirs/m1092/xju/miniconda3/envs/py2/lib/python2.7/site-packages/matplotlib/__init__.pyc'>

# %%
import os

# %%
# %%bash
# which python
# which gcc
# echo $LD_LIBRARY_PATH
# Out:
# /global/project/projectdirs/m1092/xju/miniconda3/envs/py2/bin/python
# /opt/gcc/7.3.0/bin/gcc
# /global/homes/x/xju/project/xju/miniconda3/envs/py2/lib:/opt/gcc/7.3.0/snos/lib64:/usr/common/software/globus/6.0/lib:/opt/cray/job/2.2.2-6.0.5.0_8.47__g3c644b5.ari/lib64:/opt/intel/compilers_and_libraries_2018.1.163/linux/compiler/lib/intel64:/opt/intel/compilers_and_libraries_2018.1.163/linux/mkl/lib/intel64:/usr/syscom/nsg/lib

# %%
in_dir = 'inputs/monoJetTest'

# %%
data_wenu_200 = yoda.read("Rivet_200_reco.yoda")
truth_wenu200 = data_wenu_200['/ATLAS_2017_I1635274/METNoEle_Truth']
truth_wenu200.setAnnotation("Title", "Truth Wenu 200")

reco_wenu200 = data_wenu_200['/ATLAS_2017_I1635274/METNoEle_Reco']
reco_wenu200.setAnnotation("Title", "Reco Wenu 200")
fig, ax = yoda.plot([truth_wenu200, reco_wenu200])

# %%
data2 = yoda.read("Rivet_150.yoda")
truth_hist = data2['/ATLAS_2017_I1635274/METNoEle_Truth']
truth_hist.setAnnotation("Title", "Truth")

reco_hist = data2['/ATLAS_2017_I1635274/METNoEle_Reco']
reco_hist.setAnnotation("Title", "Reco")
yoda.plot([truth_hist, reco_hist])
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fba0f8dd0>, None))

# %%
data200 = yoda.read("Rivet_Wmunu_200_reco.yoda")
truth200 = data200['/ATLAS_2017_I1635274/MET_Truth']
truth200.setAnnotation("Title", "Truth Wmunu 200")

reco200 = data200['/ATLAS_2017_I1635274/MET_Reco']
reco200.setAnnotation("Title", "Reco Wmunu 200")
yoda.plot([truth200, reco200])
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb45ba50>, None))

# %%
data3 = yoda.read("Rivet_Wmunu_150_reco.yoda")
truth_hist = data3['/ATLAS_2017_I1635274/MET_Truth']
truth_hist.setAnnotation("Title", "Truth Wmunu 150")

reco_hist = data3['/ATLAS_2017_I1635274/MET_Reco']
reco_hist.setAnnotation("Title", "Reco Wmunu 150")
yoda.plot([truth_hist, reco_hist])
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb256e90>, None))

# %%
def integral(hist, low, high):
    start = hist.binIndexAt(low)
    end = hist.binIndexAt(high)
    sum_ = sum([hist[i].area for i in range(start, end)])
    return sum_

# %%
print integral(truth_hist, 250, 999)
print integral(truth200, 250, 999)
# Out:
# 245134.28236
# 244100.68407

# %%
import numpy as np

# %%
truth_hist.setAnnotation("ratioref", True)
plot_keys = {
    "errorbar": True,
    "logY": True
}
fig, ax = yoda.plot([truth_hist, truth200], **plot_keys)
ax[0].plot([250, 250], [0, 20000], 'b-', lw=2)

# %%
tag = '/ATLAS_2017_I1635274/d01-x01-y01'
h1 = data200[tag]
h1.setAnnotation("Title", "200 GeV Cut")

h2 = data3[tag]
h2.setAnnotation("ratioref", True)
h2.setAnnotation("Title", "150 GeV Cut")
plot_keys = {
    "errorbars": False,
    'logY': True
}
yoda.plot([h2, h1], outfile="hello.pdf", **plot_keys)
# Out:
# (<Figure size 576x576 with 2 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb1dc110>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb20e050>))

# %%
yoda.plot([truth200, truth_wenu200])
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb179090>, None))

# %%
data_wmunu_200_truth = yoda.read("Rivet_Wmunu_200_truth.yoda")

# %%
dphi = data_wmunu_200_truth['/ATLAS_2017_I1635274/dPhiNorm']
yoda.plot(dphi)

# %%
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb13c290>, None))

# %%
mT = data_wmunu_200_truth['/ATLAS_2017_I1635274/munu_mT']
yoda.plot(mT)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb496410>, None))

# %%
n_muons = data_wmunu_200_truth['/ATLAS_2017_I1635274/nMuons']
yoda.plot(n_muons)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb112890>, None))

# %%
MET = data_wmunu_200_truth['/ATLAS_2017_I1635274/MET_Truth']
yoda.plot(MET)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbafca150>, None))

# %%
data_wenu_200_truth = yoda.read("Rivet_200_truth.yoda")
mT_enu = data_wenu_200_truth['/ATLAS_2017_I1635274/enu_mT']
yoda.plot(mT_enu)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb041dd0>, None))

# %%
dphi = data_wenu_200_truth['/ATLAS_2017_I1635274/dPhiNorm']
yoda.plot(dphi)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbafb4f50>, None))

# %%
n_electrons = data_wenu_200_truth['/ATLAS_2017_I1635274/nEletrons']
yoda.plot(n_electrons)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb767510>, None))

# %%
data_wmunu_200_reco = yoda.read(os.path.join(in_dir, "Rivet_Wmunu_200_reco_more_var.yoda"))

# %%
h_muons_afterRM = data_wmunu_200_reco['/ATLAS_2017_I1635274/nMuons']
h_muons_afterRM.setAnnotation("Title", "afterRM")

h_muons_noRM = data_wmunu_200_reco['/ATLAS_2017_I1635274/nMuonsNoRM']
h_muons_noRM.setAnnotation("ratioref", True)
h_muons_noRM.setAnnotation("Title", "no RM")

yoda.plot([h_muons_afterRM, h_muons_noRM])
# Out:
# (<Figure size 576x576 with 2 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb78b5d0>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb7a1490>))

# %%
data_wmunu_200_recoNoMuOR = yoda.read(os.path.join(in_dir, "Rivet_Wmunu_200_reco_NoMuonOR.yoda"))
h_muons_afterRM2 = data_wmunu_200_recoNoMuOR['/ATLAS_2017_I1635274/nMuons']
h_muons_afterRM2.setAnnotation("Title", "afterRM")

h_muons_noRM2 = data_wmunu_200_recoNoMuOR['/ATLAS_2017_I1635274/nMuonsNoRM']
h_muons_noRM2.setAnnotation("ratioref", True)
h_muons_noRM2.setAnnotation("Title", "no RM")

yoda.plot([h_muons_afterRM2, h_muons_noRM2])
# Out:
# (<Figure size 576x576 with 2 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb847550>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb885190>))

# %%
yoda.plot([data_wmunu_200_recoNoMuOR['/ATLAS_2017_I1635274/munu_mT']])
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb7e90d0>, None))

# %%
data_wmunu_final = yoda.read(os.path.join(in_dir, "Rivet_Wmunu_200_reco_NEWMT.yoda"))
yoda.plot([data_wmunu_final['/ATLAS_2017_I1635274/munu_mT']])
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb960a90>, None))

# %%
yoda.plot([data_wmunu_final['/ATLAS_2017_I1635274/nMuons']])
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x2b4fbb9e27d0>, None))
